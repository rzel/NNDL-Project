# %%
from HighwayNetworks import test_Highway
test_Highway(learning_rate=0.01, n_epochs=200, n_hidden=100, n_layers=10,
                    dataset='mnist.pkl.gz', batch_size=500, verbose = True)
# Out:
# ... loading data
# ... building the model
# training @ iter =  0
# epoch 1, minibatch 100/100, validation error 17.490000 %
#      epoch 1, minibatch 100/100, test error of best model 17.760000 %
# training @ iter =  100
# epoch 2, minibatch 100/100, validation error 9.730000 %
#      epoch 2, minibatch 100/100, test error of best model 10.280000 %
# training @ iter =  200
# epoch 3, minibatch 100/100, validation error 7.610000 %
#      epoch 3, minibatch 100/100, test error of best model 7.950000 %
# training @ iter =  300
# epoch 4, minibatch 100/100, validation error 6.190000 %
#      epoch 4, minibatch 100/100, test error of best model 6.470000 %
# training @ iter =  400
# epoch 5, minibatch 100/100, validation error 5.100000 %
#      epoch 5, minibatch 100/100, test error of best model 5.490000 %
# training @ iter =  500
# epoch 6, minibatch 100/100, validation error 4.600000 %
#      epoch 6, minibatch 100/100, test error of best model 4.940000 %
# training @ iter =  600
# ...

# %%
from HighwayNetworks import test_Highway
test_Highway(learning_rate=0.01, n_epochs=200, n_hidden=50, n_hiddenLayers=3, n_highwayLayers = 10, 
                 dataset='mnist.pkl.gz', batch_size=500,verbose=True)
# Out:
# Using gpu device 0: GeForce GTX 960M (CNMeM is disabled, cuDNN 5103)
# /usr/local/lib/python2.7/dist-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)
# /usr/local/lib/python2.7/dist-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... loading data
# ... building the model
# epoch 1, minibatch 100/100, validation error 12.830000 %
#      epoch 1, minibatch 100/100, test error of best model 13.570000 %
# epoch 2, minibatch 100/100, validation error 5.950000 %
#      epoch 2, minibatch 100/100, test error of best model 6.190000 %
# epoch 3, minibatch 100/100, validation error 4.890000 %
# ...
